# %%
import os
os.chdir('/content/drive/Shareddrives/La(LA)LAB/Research Projects/kc-coding/Code')

# %%
# Import necessary functions
from run_pipeline import (
    load_data,
    run_full_pipeline,
    collect_metrics,
    generate_report,
    save_report
)

# Set up OpenAI API key
import os
os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

# Load the data
data = load_data()

# Run the full pipeline with custom embedding path and max_length
results_dirs = run_full_pipeline(
    data,
    use_weights=True,
    embedding_path='/content/drive/MyDrive/crawl-300d-2M-subword.bin',
    max_length=50
)

# Collect and process metrics
metrics = collect_metrics(results_dirs)

# Generate and save report
report = generate_report(metrics, os.environ['OPENAI_API_KEY'])
base_dir = os.path.dirname(os.getcwd())
report_path = save_report(report, base_dir)

# Display the report
from IPython.display import Markdown, display
display(Markdown(report))
# Out:
# Running Traditional ML Experiments...
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Running Deep Learning (LSTM) Experiments...
#
# Class weights:
# Class 0: 0.37
# Class 1: 2.80
# Class 2: 0.99
# Class 3: 5.60
# Class 4: 1.97
# Class 5: 0.82
#
# Model parameters:
# Vocabulary size: 2560
# Number of classes: 6
# Sequence length: 50
#
# Loading embeddings from: /content/drive/MyDrive/crawl-300d-2M-subword.bin
# Embedding matrix shape: (2560, 300)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, 50, 300)             │         768,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 50, 256)             │         439,296 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 50, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d                 │ (None, 256)                 │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 6)                   │             390 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,248,838 (4.76 MB)
#  Trainable params: 480,838 (1.83 MB)
#  Non-trainable params: 768,000 (2.93 MB)
# Starting model training...
# Initial learning rate: 0.0010000000474974513
# Epoch 1/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2428 - loss: 3.4908 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 1: val_loss improved from inf to 2.10823, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.2426 - loss: 3.4622 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1655 - val_loss: 2.1082 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1668 - loss: 2.0180 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: val_loss improved from 2.10823 to 1.79166, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1671 - loss: 2.0155 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2818 - val_loss: 1.7917 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2729 - loss: 1.7857 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: val_loss improved from 1.79166 to 1.75563, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2715 - loss: 1.7843 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1559 - val_loss: 1.7556 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/150
# 102/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2258 - loss: 1.7061 - precision: 0.1814 - recall: 1.3720e-04
# Epoch 4: val_loss improved from 1.75563 to 1.70362, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2251 - loss: 1.7062 - precision: 0.1934 - recall: 1.4338e-04 - val_accuracy: 0.2230 - val_loss: 1.7036 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2090 - loss: 1.7212 - precision: 0.5094 - recall: 0.0098
# Epoch 5: val_loss improved from 1.70362 to 1.67556, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2090 - loss: 1.7208 - precision: 0.5101 - recall: 0.0098 - val_accuracy: 0.2398 - val_loss: 1.6756 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 6/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2413 - loss: 1.6803 - precision: 0.8705 - recall: 0.0059
# Epoch 6: val_loss did not improve from 1.67556
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2411 - loss: 1.6796 - precision: 0.8696 - recall: 0.0059 - val_accuracy: 0.1751 - val_loss: 1.6865 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2502 - loss: 1.6435 - precision: 0.9193 - recall: 0.0131
# Epoch 7: val_loss improved from 1.67556 to 1.67044, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2502 - loss: 1.6428 - precision: 0.9163 - recall: 0.0134 - val_accuracy: 0.1906 - val_loss: 1.6704 - val_precision: 0.8000 - val_recall: 0.0048 - learning_rate: 0.0010
# Epoch 8/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2176 - loss: 1.6697 - precision: 0.8209 - recall: 0.0239
# Epoch 8: val_loss improved from 1.67044 to 1.61427, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2178 - loss: 1.6692 - precision: 0.8210 - recall: 0.0239 - val_accuracy: 0.2914 - val_loss: 1.6143 - val_precision: 0.9048 - val_recall: 0.0228 - learning_rate: 0.0010
# Epoch 9/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2350 - loss: 1.5974 - precision: 0.7533 - recall: 0.0439
# Epoch 9: val_loss did not improve from 1.61427
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2355 - loss: 1.5972 - precision: 0.7535 - recall: 0.0439 - val_accuracy: 0.2182 - val_loss: 1.6436 - val_precision: 0.9130 - val_recall: 0.0252 - learning_rate: 0.0010
# Epoch 10/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2402 - loss: 1.5675 - precision: 0.7895 - recall: 0.0488
# Epoch 10: val_loss did not improve from 1.61427
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2404 - loss: 1.5679 - precision: 0.7883 - recall: 0.0487 - val_accuracy: 0.2170 - val_loss: 1.6391 - val_precision: 1.0000 - val_recall: 0.0180 - learning_rate: 0.0010
# Epoch 11/150
# 100/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2577 - loss: 1.5370 - precision: 0.8191 - recall: 0.0466
# Epoch 11: val_loss improved from 1.61427 to 1.60717, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2575 - loss: 1.5383 - precision: 0.8197 - recall: 0.0467 - val_accuracy: 0.2038 - val_loss: 1.6072 - val_precision: 0.8235 - val_recall: 0.0504 - learning_rate: 0.0010
# Epoch 12/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2781 - loss: 1.5211 - precision: 0.7737 - recall: 0.0661
# Epoch 12: val_loss did not improve from 1.60717
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2782 - loss: 1.5214 - precision: 0.7737 - recall: 0.0661 - val_accuracy: 0.2482 - val_loss: 1.6202 - val_precision: 0.8824 - val_recall: 0.0360 - learning_rate: 0.0010
# Epoch 13/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2928 - loss: 1.5018 - precision: 0.8330 - recall: 0.0761
# Epoch 13: val_loss improved from 1.60717 to 1.56364, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2934 - loss: 1.5020 - precision: 0.8329 - recall: 0.0765 - val_accuracy: 0.2794 - val_loss: 1.5636 - val_precision: 0.7083 - val_recall: 0.0612 - learning_rate: 0.0010
# Epoch 14/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3017 - loss: 1.4634 - precision: 0.7398 - recall: 0.0998
# Epoch 14: val_loss did not improve from 1.56364
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3008 - loss: 1.4652 - precision: 0.7388 - recall: 0.0992 - val_accuracy: 0.1535 - val_loss: 1.6694 - val_precision: 1.0000 - val_recall: 0.0012 - learning_rate: 0.0010
# Epoch 15/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1979 - loss: 1.5514 - precision: 0.6971 - recall: 0.0206
# Epoch 15: val_loss did not improve from 1.56364
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.1986 - loss: 1.5515 - precision: 0.6979 - recall: 0.0210 - val_accuracy: 0.2086 - val_loss: 1.6273 - val_precision: 0.7679 - val_recall: 0.0516 - learning_rate: 0.0010
# Epoch 16/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2478 - loss: 1.5164 - precision: 0.7314 - recall: 0.0571
# Epoch 16: val_loss did not improve from 1.56364
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2489 - loss: 1.5161 - precision: 0.7310 - recall: 0.0575 - val_accuracy: 0.2074 - val_loss: 1.6521 - val_precision: 0.8036 - val_recall: 0.0540 - learning_rate: 0.0010
# Epoch 17/150
# 102/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2458 - loss: 1.5170 - precision: 0.7456 - recall: 0.0650
# Epoch 17: val_loss did not improve from 1.56364
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2459 - loss: 1.5164 - precision: 0.7452 - recall: 0.0650 - val_accuracy: 0.2050 - val_loss: 1.6079 - val_precision: 0.8542 - val_recall: 0.0492 - learning_rate: 0.0010
# Epoch 18/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2663 - loss: 1.4608 - precision: 0.7988 - recall: 0.0758
# Epoch 18: val_loss did not improve from 1.56364
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2663 - loss: 1.4611 - precision: 0.7988 - recall: 0.0757 - val_accuracy: 0.2650 - val_loss: 1.6031 - val_precision: 0.7037 - val_recall: 0.0683 - learning_rate: 0.0010
# Epoch 19/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2615 - loss: 1.4455 - precision: 0.7442 - recall: 0.0903
# Epoch 19: val_loss improved from 1.56364 to 1.54605, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2615 - loss: 1.4460 - precision: 0.7460 - recall: 0.0901 - val_accuracy: 0.3189 - val_loss: 1.5460 - val_precision: 0.6275 - val_recall: 0.0767 - learning_rate: 5.0000e-04
# Epoch 20/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3139 - loss: 1.4194 - precision: 0.7673 - recall: 0.1021
# Epoch 20: val_loss did not improve from 1.54605
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3136 - loss: 1.4203 - precision: 0.7684 - recall: 0.1017 - val_accuracy: 0.3153 - val_loss: 1.5512 - val_precision: 0.6000 - val_recall: 0.0755 - learning_rate: 5.0000e-04
# Epoch 21/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3012 - loss: 1.3951 - precision: 0.7531 - recall: 0.0926
# Epoch 21: val_loss did not improve from 1.54605
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3013 - loss: 1.3952 - precision: 0.7534 - recall: 0.0926 - val_accuracy: 0.2470 - val_loss: 1.5972 - val_precision: 0.7808 - val_recall: 0.0683 - learning_rate: 5.0000e-04
# Epoch 22/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3162 - loss: 1.4007 - precision: 0.8208 - recall: 0.0883
# Epoch 22: val_loss did not improve from 1.54605
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3162 - loss: 1.4013 - precision: 0.8203 - recall: 0.0887 - val_accuracy: 0.2926 - val_loss: 1.5749 - val_precision: 0.7978 - val_recall: 0.0851 - learning_rate: 5.0000e-04
# Epoch 23/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3456 - loss: 1.3452 - precision: 0.8007 - recall: 0.1189
# Epoch 23: val_loss did not improve from 1.54605
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3456 - loss: 1.3456 - precision: 0.8008 - recall: 0.1188 - val_accuracy: 0.2998 - val_loss: 1.5592 - val_precision: 0.8305 - val_recall: 0.1175 - learning_rate: 5.0000e-04
# Epoch 24/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3079 - loss: 1.3878 - precision: 0.7628 - recall: 0.1117
# Epoch 24: val_loss improved from 1.54605 to 1.50975, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3085 - loss: 1.3879 - precision: 0.7634 - recall: 0.1121 - val_accuracy: 0.3309 - val_loss: 1.5098 - val_precision: 0.8295 - val_recall: 0.1283 - learning_rate: 5.0000e-04
# Epoch 25/150
# 102/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3554 - loss: 1.3732 - precision: 0.7728 - recall: 0.1395
# Epoch 25: val_loss did not improve from 1.50975
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3551 - loss: 1.3733 - precision: 0.7724 - recall: 0.1393 - val_accuracy: 0.3201 - val_loss: 1.5180 - val_precision: 0.8017 - val_recall: 0.1115 - learning_rate: 5.0000e-04
# Epoch 26/150
# 102/105 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3568 - loss: 1.4067 - precision: 0.7063 - recall: 0.1346
# Epoch 26: val_loss did not improve from 1.50975
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3566 - loss: 1.4055 - precision: 0.7081 - recall: 0.1345 - val_accuracy: 0.3141 - val_loss: 1.5416 - val_precision: 0.8333 - val_recall: 0.1319 - learning_rate: 5.0000e-04
# Epoch 27/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3579 - loss: 1.3873 - precision: 0.7561 - recall: 0.1490
# Epoch 27: val_loss did not improve from 1.50975
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3580 - loss: 1.3856 - precision: 0.7555 - recall: 0.1489 - val_accuracy: 0.3417 - val_loss: 1.5329 - val_precision: 0.7151 - val_recall: 0.1595 - learning_rate: 5.0000e-04
# Epoch 28/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3619 - loss: 1.3141 - precision: 0.6913 - recall: 0.1694
# Epoch 28: val_loss improved from 1.50975 to 1.50714, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3626 - loss: 1.3144 - precision: 0.6913 - recall: 0.1695 - val_accuracy: 0.3525 - val_loss: 1.5071 - val_precision: 0.7053 - val_recall: 0.1607 - learning_rate: 5.0000e-04
# Epoch 29/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3583 - loss: 1.3617 - precision: 0.6065 - recall: 0.1579
# Epoch 29: val_loss did not improve from 1.50714
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3596 - loss: 1.3591 - precision: 0.6074 - recall: 0.1587 - val_accuracy: 0.3405 - val_loss: 1.5192 - val_precision: 0.6386 - val_recall: 0.1906 - learning_rate: 5.0000e-04
# Epoch 30/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3862 - loss: 1.2809 - precision: 0.5950 - recall: 0.1803
# Epoch 30: val_loss improved from 1.50714 to 1.50105, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3863 - loss: 1.2821 - precision: 0.5954 - recall: 0.1804 - val_accuracy: 0.3705 - val_loss: 1.5011 - val_precision: 0.6574 - val_recall: 0.1703 - learning_rate: 5.0000e-04
# Epoch 31/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3907 - loss: 1.3178 - precision: 0.6675 - recall: 0.2108
# Epoch 31: val_loss did not improve from 1.50105
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3906 - loss: 1.3168 - precision: 0.6668 - recall: 0.2107 - val_accuracy: 0.3621 - val_loss: 1.5113 - val_precision: 0.6330 - val_recall: 0.2026 - learning_rate: 5.0000e-04
# Epoch 32/150
# 100/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4073 - loss: 1.2401 - precision: 0.6008 - recall: 0.2256
# Epoch 32: val_loss did not improve from 1.50105
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4072 - loss: 1.2410 - precision: 0.6003 - recall: 0.2249 - val_accuracy: 0.3141 - val_loss: 1.6026 - val_precision: 0.4907 - val_recall: 0.1583 - learning_rate: 5.0000e-04
# Epoch 33/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4096 - loss: 1.2656 - precision: 0.5991 - recall: 0.2189
# Epoch 33: val_loss improved from 1.50105 to 1.48320, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4097 - loss: 1.2653 - precision: 0.5991 - recall: 0.2189 - val_accuracy: 0.3825 - val_loss: 1.4832 - val_precision: 0.5392 - val_recall: 0.1978 - learning_rate: 5.0000e-04
# Epoch 34/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4103 - loss: 1.2105 - precision: 0.5890 - recall: 0.2426
# Epoch 34: val_loss did not improve from 1.48320
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4103 - loss: 1.2107 - precision: 0.5888 - recall: 0.2425 - val_accuracy: 0.3321 - val_loss: 1.5161 - val_precision: 0.5269 - val_recall: 0.1763 - learning_rate: 5.0000e-04
# Epoch 35/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4100 - loss: 1.2127 - precision: 0.5950 - recall: 0.2391
# Epoch 35: val_loss improved from 1.48320 to 1.45110, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4101 - loss: 1.2124 - precision: 0.5947 - recall: 0.2391 - val_accuracy: 0.4365 - val_loss: 1.4511 - val_precision: 0.6115 - val_recall: 0.2302 - learning_rate: 5.0000e-04
# Epoch 36/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4447 - loss: 1.1812 - precision: 0.6007 - recall: 0.2612
# Epoch 36: val_loss did not improve from 1.45110
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4445 - loss: 1.1810 - precision: 0.6004 - recall: 0.2613 - val_accuracy: 0.4029 - val_loss: 1.4571 - val_precision: 0.5452 - val_recall: 0.2386 - learning_rate: 5.0000e-04
# Epoch 37/150
# 100/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4128 - loss: 1.1742 - precision: 0.5806 - recall: 0.2815
# Epoch 37: val_loss did not improve from 1.45110
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4140 - loss: 1.1760 - precision: 0.5803 - recall: 0.2810 - val_accuracy: 0.2938 - val_loss: 1.6293 - val_precision: 0.4557 - val_recall: 0.1667 - learning_rate: 5.0000e-04
# Epoch 38/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4325 - loss: 1.1945 - precision: 0.5767 - recall: 0.2629
# Epoch 38: val_loss did not improve from 1.45110
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4322 - loss: 1.1945 - precision: 0.5768 - recall: 0.2628 - val_accuracy: 0.3765 - val_loss: 1.4976 - val_precision: 0.5781 - val_recall: 0.2086 - learning_rate: 5.0000e-04
# Epoch 39/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4384 - loss: 1.1465 - precision: 0.6003 - recall: 0.2822
# Epoch 39: val_loss did not improve from 1.45110
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4385 - loss: 1.1470 - precision: 0.5996 - recall: 0.2822 - val_accuracy: 0.3873 - val_loss: 1.4895 - val_precision: 0.5378 - val_recall: 0.2134 - learning_rate: 5.0000e-04
# Epoch 40/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4393 - loss: 1.2071 - precision: 0.5919 - recall: 0.2754
# Epoch 40: val_loss improved from 1.45110 to 1.41676, saving model to ../Results/neural_networks/lstm/weighted/run_20241228_023015/models/weights/best.weights.h5
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4393 - loss: 1.2067 - precision: 0.5917 - recall: 0.2753 - val_accuracy: 0.4173 - val_loss: 1.4168 - val_precision: 0.5422 - val_recall: 0.2542 - learning_rate: 5.0000e-04
# Epoch 41/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4457 - loss: 1.1426 - precision: 0.5810 - recall: 0.2894
# Epoch 41: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4457 - loss: 1.1426 - precision: 0.5810 - recall: 0.2894 - val_accuracy: 0.4161 - val_loss: 1.4444 - val_precision: 0.5425 - val_recall: 0.2602 - learning_rate: 5.0000e-04
# Epoch 42/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4618 - loss: 1.1347 - precision: 0.6160 - recall: 0.3099
# Epoch 42: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4619 - loss: 1.1343 - precision: 0.6159 - recall: 0.3100 - val_accuracy: 0.4113 - val_loss: 1.4373 - val_precision: 0.5157 - val_recall: 0.2554 - learning_rate: 5.0000e-04
# Epoch 43/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4643 - loss: 1.1085 - precision: 0.5833 - recall: 0.3171
# Epoch 43: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4642 - loss: 1.1081 - precision: 0.5837 - recall: 0.3171 - val_accuracy: 0.4173 - val_loss: 1.4315 - val_precision: 0.5322 - val_recall: 0.2578 - learning_rate: 5.0000e-04
# Epoch 44/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4716 - loss: 1.1154 - precision: 0.5758 - recall: 0.3272
# Epoch 44: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4715 - loss: 1.1153 - precision: 0.5759 - recall: 0.3272 - val_accuracy: 0.4053 - val_loss: 1.4978 - val_precision: 0.5369 - val_recall: 0.2614 - learning_rate: 5.0000e-04
# Epoch 45/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4603 - loss: 1.1120 - precision: 0.5936 - recall: 0.2993
# Epoch 45: val_loss did not improve from 1.41676
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4603 - loss: 1.1117 - precision: 0.5938 - recall: 0.2995 - val_accuracy: 0.3693 - val_loss: 1.5046 - val_precision: 0.4591 - val_recall: 0.2290 - learning_rate: 5.0000e-04
# Epoch 46/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4764 - loss: 1.0774 - precision: 0.6015 - recall: 0.3252
# Epoch 46: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4768 - loss: 1.0758 - precision: 0.6016 - recall: 0.3256 - val_accuracy: 0.4221 - val_loss: 1.4613 - val_precision: 0.5677 - val_recall: 0.2866 - learning_rate: 2.5000e-04
# Epoch 47/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4856 - loss: 1.0465 - precision: 0.6077 - recall: 0.3447
# Epoch 47: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4856 - loss: 1.0464 - precision: 0.6077 - recall: 0.3448 - val_accuracy: 0.4365 - val_loss: 1.4361 - val_precision: 0.5584 - val_recall: 0.2926 - learning_rate: 2.5000e-04
# Epoch 48/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4996 - loss: 1.0009 - precision: 0.6249 - recall: 0.3477
# Epoch 48: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4996 - loss: 1.0010 - precision: 0.6249 - recall: 0.3478 - val_accuracy: 0.4329 - val_loss: 1.4314 - val_precision: 0.5599 - val_recall: 0.2914 - learning_rate: 2.5000e-04
# Epoch 49/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5025 - loss: 0.9772 - precision: 0.6230 - recall: 0.3734
# Epoch 49: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5024 - loss: 0.9779 - precision: 0.6228 - recall: 0.3730 - val_accuracy: 0.4353 - val_loss: 1.4475 - val_precision: 0.5548 - val_recall: 0.2974 - learning_rate: 2.5000e-04
# Epoch 50/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4963 - loss: 0.9566 - precision: 0.6154 - recall: 0.3689
# Epoch 50: val_loss did not improve from 1.41676
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4967 - loss: 0.9584 - precision: 0.6155 - recall: 0.3689 - val_accuracy: 0.4197 - val_loss: 1.4526 - val_precision: 0.5032 - val_recall: 0.2866 - learning_rate: 2.5000e-04
# Epoch 51/150
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5039 - loss: 1.0101 - precision: 0.6289 - recall: 0.3660
# Epoch 51: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5041 - loss: 1.0091 - precision: 0.6289 - recall: 0.3661 - val_accuracy: 0.4353 - val_loss: 1.4402 - val_precision: 0.5430 - val_recall: 0.3106 - learning_rate: 1.2500e-04
# Epoch 52/150
# 101/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5132 - loss: 0.9823 - precision: 0.6135 - recall: 0.3753
# Epoch 52: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5133 - loss: 0.9818 - precision: 0.6141 - recall: 0.3756 - val_accuracy: 0.4329 - val_loss: 1.4460 - val_precision: 0.5383 - val_recall: 0.3118 - learning_rate: 1.2500e-04
# Epoch 53/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5203 - loss: 0.9385 - precision: 0.6225 - recall: 0.3855
# Epoch 53: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5201 - loss: 0.9390 - precision: 0.6226 - recall: 0.3854 - val_accuracy: 0.4365 - val_loss: 1.4412 - val_precision: 0.5411 - val_recall: 0.3082 - learning_rate: 1.2500e-04
# Epoch 54/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5338 - loss: 0.9495 - precision: 0.6386 - recall: 0.4103
# Epoch 54: val_loss did not improve from 1.41676
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5337 - loss: 0.9495 - precision: 0.6385 - recall: 0.4101 - val_accuracy: 0.4472 - val_loss: 1.4438 - val_precision: 0.5492 - val_recall: 0.3213 - learning_rate: 1.2500e-04
# Epoch 55/150
# 102/105 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5326 - loss: 0.9738 - precision: 0.6350 - recall: 0.4007
# Epoch 55: val_loss did not improve from 1.41676
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5317 - loss: 0.9731 - precision: 0.6347 - recall: 0.4005 - val_accuracy: 0.4376 - val_loss: 1.4374 - val_precision: 0.5526 - val_recall: 0.3213 - learning_rate: 1.2500e-04
#
# Loading best weights for final evaluation...
#
# Evaluating model with best weights...
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4119 - loss: 1.4416 - precision: 0.5448 - recall: 0.2451
#
# Running Transformer (RoBERTa) Experiments...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/3333 [00:00<?, ? examples/s]
# Map:   0%|          | 0/834 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#   0%|          | 0/1040 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='1000' max='1040' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1040 03:45 < 00:09, 4.42 it/s, Epoch 9/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>3.084900</td>
#       <td>1.493709</td>
#       <td>0.454436</td>
#       <td>0.283976</td>
#       <td>0.206512</td>
#       <td>0.454436</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.721400</td>
#       <td>1.386295</td>
#       <td>0.491607</td>
#       <td>0.376364</td>
#       <td>0.323668</td>
#       <td>0.491607</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.613200</td>
#       <td>1.206739</td>
#       <td>0.547962</td>
#       <td>0.453707</td>
#       <td>0.435035</td>
#       <td>0.547962</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.353800</td>
#       <td>1.139640</td>
#       <td>0.573141</td>
#       <td>0.472105</td>
#       <td>0.492037</td>
#       <td>0.573141</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.121300</td>
#       <td>1.114361</td>
#       <td>0.586331</td>
#       <td>0.519741</td>
#       <td>0.523424</td>
#       <td>0.586331</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.226800</td>
#       <td>1.065745</td>
#       <td>0.597122</td>
#       <td>0.547933</td>
#       <td>0.533320</td>
#       <td>0.597122</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.949600</td>
#       <td>1.043127</td>
#       <td>0.606715</td>
#       <td>0.568795</td>
#       <td>0.543916</td>
#       <td>0.606715</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1

#   0%|          | 0/53 [00:00<?, ?it/s]
# {'eval_loss': 1.0060757398605347, 'eval_accuracy': 0.6270983213429256, 'eval_f1': 0.6011777525800465, 'eval_precision': 0.5946789762241805, 'eval_recall': 0.6270983213429256, 'eval_runtime': 0.9109, 'eval_samples_per_second': 915.611, 'eval_steps_per_second': 58.186, 'epoch': 5.72}
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'loss': 1.7125, 'grad_norm': 37.222347259521484, 'learning_rate': 1.3819148936170215e-05, 'epoch': 5.81}
# {'loss': 1.6406, 'grad_norm': 40.382408142089844, 'learning_rate': 1.3500000000000001e-05, 'epoch': 5.91}
# {'loss': 1.7599, 'grad_norm': 25.393014907836914, 'learning_rate': 1.3180851063829788e-05, 'epoch': 6.0}
# {'loss': 1.503, 'grad_norm': 48.88917541503906, 'learning_rate': 1.2861702127659574e-05, 'epoch': 6.1}
# {'loss': 1.5245, 'grad_norm': 37.263145446777344, 'learning_rate': 1.2542553191489362e-05, 'epoch': 6.19}
#   0%|          | 0/53 [00:00<?, ?it/s]
# {'eval_loss': 1.0174133777618408, 'eval_accuracy': 0.6294964028776978, 'eval_f1': 0.6133583646083115, 'eval_precision': 0.6061695762241155, 'eval_recall': 0.6294964028776978, 'eval_runtime': 0.9318, 'eval_samples_per_second': 895.085, 'eval_steps_per_second': 56.882, 'epoch': 6.19}
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'loss': 1.7074, 'grad_norm': 32.50111389160156, 'learning_rate': 1.2223404255319149e-05, 'epoch': 6.29}
# {'loss': 1.5362, 'grad_norm': 46.463191986083984, 'learning_rate': 1.1904255319148935e-05, 'epoch': 6.38}
# {'loss': 1.7288, 'grad_norm': 64.15861511230469, 'learning_rate': 1.1585106382978724e-05, 'epoch': 6.48}
# {'loss': 1.4605, 'grad_norm': 36.61310958862305, 'learning_rate': 1.1265957446808512e-05, 'epoch': 6.57}
# {'loss': 1.8393, 'grad_norm': 37.22502899169922, 'learning_rate': 1.0946808510638298e-05, 'epoch': 6.67}
#   0%|          | 0/53 [00:00<?, ?it/s]
# {'eval_loss': 0.9968103170394897, 'eval_accuracy': 0.6294964028776978, 'eval_f1': 0.621964345255924, 'eval_precision': 0.6168683238082837, 'eval_recall': 0.6294964028776978, 'eval_runtime': 0.9552, 'eval_samples_per_second': 873.084, 'eval_steps_per_second': 55.484, 'epoch': 6.67}
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'loss': 1.6843, 'grad_norm': 46.41348648071289, 'learning_rate': 1.0627659574468085e-05, 'epoch': 6.77}
# {'loss': 1.4241, 'grad_norm': 40.305015563964844, 'learning_rate': 1.0308510638297873e-05, 'epoch': 6.86}
# {'loss': 1.5826, 'grad_norm': 41.805850982666016, 'learning_rate': 9.98936170212766e-06, 'epoch': 6.96}
# {'loss': 1.5433, 'grad_norm': 33.049617767333984, 'learning_rate': 9.670212765957446e-06, 'epoch': 7.05}
# {'loss': 1.4109, 'grad_norm': 31.789737701416016, 'learning_rate': 9.351063829787234e-06, 'epoch': 7.14}
#   0%|          | 0/53 [00:00<?, ?it/s]
# {'eval_loss': 1.

# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'loss': 1.3115, 'grad_norm': 33.794212341308594, 'learning_rate': 4.2765957446808515e-06, 'epoch': 8.67}
# {'loss': 1.3466, 'grad_norm': 45.98666000366211, 'learning_rate': 3.957446808510638e-06, 'epoch': 8.77}
# {'loss': 1.4508, 'grad_norm': 38.28612518310547, 'learning_rate': 3.6382978723404254e-06, 'epoch': 8.86}
# {'loss': 1.5063, 'grad_norm': 46.61606979370117, 'learning_rate': 3.3191489361702127e-06, 'epoch': 8.96}
# {'loss': 1.1164, 'grad_norm': 47.38169479370117, 'learning_rate': 3e-06, 'epoch': 9.05}
#   0%|          | 0/53 [00:00<?, ?it/s]
# {'eval_loss': 1.034414291381836, 'eval_accuracy': 0.6498800959232613, 'eval_f1': 0.6262372888805902, 'eval_precision': 0.6150859738245377, 'eval_recall': 0.6498800959232613, 'eval_runtime': 0.9376, 'eval_samples_per_second': 889.503, 'eval_steps_per_second': 56.527, 'epoch': 9.05}
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'loss': 1.3508, 'grad_norm': 40.72792434692383, 'learning_rate': 2.6808510638297874e-06, 'epoch': 9.14}
# {'loss': 1.3263, 'grad_norm': 43.306907653808594, 'learning_rate': 2.3617021276595748e-06, 'epoch': 9.24}
# {'loss': 1.3972, 'grad_norm': 39.58138656616211, 'learning_rate': 2.0425531914893617e-06, 'epoch': 9.33}
# {'loss': 1.4342, 'grad_norm': 28.68346405029297, 'learning_rate': 1.723404255319149e-06, 'epoch': 9.43}
# {'loss': 1.1814, 'grad_norm': 34.308937072753906, 'learning_rate': 1.4042553191489362e-06, 'epoch': 9.53}
#   0%|          | 0/53 [00:00<?, ?it/s]
# {'eval_loss': 1.0288887023925781, 'eval_accuracy': 0.6534772182254197, 'eval_f1': 0.6360132934824598, 'eval_precision': 0.6251416065531139, 'eval_recall': 0.6534772182254197, 'eval_runtime': 0.9255, 'eval_samples_per_second': 901.163, 'eval_steps_per_second': 57.268, 'epoch': 9.53}
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'train_runtime': 226.8023, 'train_samples_per_second': 146.956, 'train_steps_per_second': 4.585, 'train_loss': 1.9502507419586181, 'epoch': 9.53}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-fd67df17e9aa> in <cell line: 18>()
#      16
#      17 # Run the full pipeline with custom embedding path and max_length
# ---> 18 results_dirs = run_full_pipeline(
#      19     data,
#      20     use_weights=True,
#
# /content/drive/Shareddrives/La(LA)LAB/Research Projects/kc-coding/Code/run_pipeline.py in run_full_pipeline(data, use_weights, merge_codes, embedding_path, max_length)
#      44     # Run transformer experiments
#      45     print("\nRunning Transformer (RoBERTa) Experiments...")
# ---> 46     transformer_results_dir = run_transformer_experiment(
#      47         data,
#      48         merge_codes=merge_codes,
#
# /content/drive/Shareddrives/La(LA)LAB/Research Projects/kc-coding/Code/transformer_experiments.py in run_transformer_experiment(data, merge_codes, model_name, use_weights, num_epochs)
#     256
#     257     # Plot and save training curves
# --> 258     plot_training_history(history, run_dir)
#     259
#     260     # Save training history
#
# /content/drive/Shareddrives/La(LA)LAB/Research Projects/kc-coding/Code/transformer_experiments.py in plot_training_history(history, run_dir)
#      72     # Plot training loss
#      73     plt.subplot(1, 2, 1)
# ---> 74     plt.plot(history['train_loss'], label='Training')
#      75     plt.plot(history['eval_loss'], label='Validation')
#      76     plt.title('Loss Over Time')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1719         """
#    1720         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722         for line in lines:
#    1723             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, axes, data, *args, **kwargs)
#     301                 this += args[0],
#     302                 args = args[1:]
# --> 303             yield from self._plot_args(
#     304                 axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     305
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     494             axes.xaxis.update_units(x)
#     495         if axes.yaxis is not None:
# --> 496             axes.yaxis.update_units(y)
#     497
#     498         if x.shape[0] != y.shape[0]:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in update_units(self, data)
#    1710         neednew = self.converter != converter
#    1711         self.converter = converter
# -> 1712         default = self.converter.default_units(data, self)
#    1713         if default is not None and self.units is None:
#    1714             self.set_units(default)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/category.py in default_units(data, axis)
#     103         # the conversion call stack is default_units -> axis_info -> convert
#     104         if axis.units is None:
# --> 105             axis.set_units(UnitData(data))
#     106         else:
#     107             axis.units.update(data)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/category.py in __init__(self, data)
#     179         self._counter = itertools.count()
#     180         if data is not None:
# --> 181             self.update(data)
#     182
#     183     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/category.py in update(self, data)
#     212         # check if convertible to number:
#     213         convertible = True
# --> 214         for val in OrderedDict.fromkeys(data):
#     215             # OrderedDict just iterates over unique values in data.
#     216             _api.check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'dict'

# %%
# !pip install fasttext sentence_transformers datasets
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 7.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (75.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.26.4)
# Using cached pybind11-2.13.6-py3-none-any.whl (243 kB)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp310-cp310-linux_x86_64.whl size=4296184 sha256=a3230bb5ed90497570e6b7ea9387171d0b00133a527331fcf0e76c7e907bd4f4
#   Stored in directory: /root/.cache/pip/wheels/0d/a2/00/81db54d3e6a8199b829d58e02cec2ddb20ce3e59fad8d3c92a
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.3 pybind11-2.13.6

# %%
pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 36.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.1 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 21.3 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.2 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.5 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0
